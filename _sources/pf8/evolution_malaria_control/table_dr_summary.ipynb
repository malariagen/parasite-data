# %% [markdown]
# # Plot drug resistance frequencies

# %% [markdown]
# ## Introduction

# %% [markdown]
# This notebook creates a table summarising the number of samples with inferred antimalarial drug resistance (DR) in different populations using the data from *Plasmodium falciparum* version 8 (Pf8) project.
#
# **This notebook takes 1 minute to run.**

# %% [markdown]
# ## Setup

# %% [markdown]
# Install and import the malariagen Python package:

# %%
# !pip install malariagen_data -q --no-warn-conflicts
import malariagen_data
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 19.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.7/71.7 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.9/775.9 kB 42.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.9/25.9 MB 66.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 94.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.6/210.6 kB 15.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 94.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 81.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 82.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 91.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.0/228.0 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 89.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 60.8 MB/s eta 0:00:00
#   Building wheel for malariagen_data (pyproject.toml) ... done
#   Building wheel for dash-cytoscape (setup.py) ... done
#   Building wheel for asciitree (setup.py) ... done

# %% [markdown]
# Import required python libraries that are installed at colab by default.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import collections
import re
import scipy

# %% [markdown]
# ## Access Pf8 Data

# %% [markdown]
# We use the malariagen data package to load the release data.

# %%
release_data = malariagen_data.Pf8()
sample_metadata = release_data.sample_metadata()

# take a glance at the metadata dataframe
sample_metadata.head(3)
# Out:
#       Sample              Study     Country   Admin level 1  Country latitude  \
# 0   FP0008-C  1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi         20.265149
# 1   FP0009-C  1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi         20.265149
# 2  FP0010-CW  1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi         20.265149
#
#    Country longitude  Admin level 1 latitude  Admin level 1 longitude    Year  \
# 0         -10.337093               16.565426                -9.832345  2014.0
# 1         -10.337093               16.565426                -9.832345  2014.0
# 2         -10.337093               16.565426                -9.832345  2014.0
#
#           ENA All samples same case Population  % callable  QC pass  \
# 0  ERR1081237              FP0008-C       AF-W       82.48     True
# 1  ERR1081238              FP0009-C       AF-W       88.95     True
# 2  ERR2889621             FP0010-CW       AF-W       87.01     True
#
#   Exclusion reason Sample type  Sample was in Pf7
# 0     Analysis_set        gDNA               True
# 1     Analysis_set        gDNA               True
# 2     Analysis_set        sWGA               True

# %% [markdown]
# We will only examine the QC pass samples in the analysis of these notebooks.

# %%
# Retain QC pass samples
qc_sample_metadata = sample_metadata.loc[sample_metadata['QC pass']]

# %% [markdown]
# ## Access DR Classification and Genotype Data

# %% [markdown]
# We can access inferred resistance status classifications of QC-pass Pf8 samples from the Sanger's cloud storage.
#
# This dataset includes the samples that are predicted to be resistant to 10 drugs or combinations of drugs and to rapid diagnostic tests (RDT) detection: chloroquine, pyrimethamine, sulfadoxine, mefloquine, artemisinin, piperaquine, sulfadoxine- pyrimethamine for treatment of uncomplicated malaria, sulfadoxine- pyrimethamine for intermittent preventive treatment in pregnancy, artesunate-mefloquine, dihydroartemisinin-piperaquine, *hrp2* and *hrp3* gene deletions.

# %%
# Read the data
resistance_classification_fn = pd.read_csv('https://pf8-release.cog.sanger.ac.uk/Pf8_inferred_resistance_status_classification.tsv', sep='\t')

# Rename the first column as 'Sample'
resistance_classification_fn = resistance_classification_fn.rename(columns={resistance_classification_fn.columns[0]: 'Sample'})

# Print the first rows
resistance_classification_fn.head()
# Out:
#       Sample   Chloroquine Pyrimethamine   Sulfadoxine Mefloquine Artemisinin  \
# 0   FP0008-C  Undetermined  Undetermined  Undetermined  Sensitive   Sensitive
# 1   FP0009-C     Resistant     Resistant     Sensitive  Sensitive   Sensitive
# 2  FP0010-CW  Undetermined     Resistant     Resistant  Sensitive   Sensitive
# 3  FP0011-CW  Undetermined     Resistant  Undetermined  Sensitive   Sensitive
# 4  FP0012-CW     Resistant     Resistant     Sensitive  Sensitive   Sensitive
#
#   Piperaquine SP (uncomplicated)  SP (IPTp)      AS-MQ    DHA-PPQ
# 0   Sensitive          Sensitive  Sensitive  Sensitive  Sensitive
# 1   Sensitive          Resistant  Sensitive  Sensitive  Sensitive
# 2   Sensitive          Resistant  Sensitive  Sensitive  Sensitive
# 3   Sensitive          Resistant  Sensitive  Sensitive  Sensitive
# 4   Sensitive          Resistant  Sensitive  Sensitive  Sensitive

# %% [markdown]
# We will also use the genotypes utilised in drug resistance status classification containing amino acid and copy number genotypes at six loci: *crt*, *dhfr*, *dhps*, *mdr1*, *kelch13*, *plasmepsin* *2-3*. This dataset is also available from the Sanger's cloud storage.

# %%
# Read the data
drm_calls_fn = pd.read_csv('https://pf8-release.cog.sanger.ac.uk/Pf8_drug_resistance_marker_genotypes.tsv', sep='\t', )

# Rename the first column as 'Sample'
drm_calls_fn = drm_calls_fn.rename(columns={drm_calls_fn.columns[0]: 'Sample'})

# Print the first rows
drm_calls_fn.head()
# Out:
#       Sample crt_72[C] crt_74[M] crt_75[N] crt_76[K] crt_72-76[CVMNK]  \
# 0   FP0008-C         C       I,M       E,N       T,K      CVIET,CVMNK
# 1   FP0009-C         C         I         E         T            CVIET
# 2  FP0010-CW         C       I,M       E,N       T,K      CVIET,CVMNK
# 3  FP0011-CW         C       I,M       E,N       T,K      CVIET,CVMNK
# 4  FP0012-CW         C         I         E         T            CVIET
#
#   crt_93[T] crt_97[H] crt_218[I] crt_220[A]  ... mdr1_1034[S] mdr1_1042[N]  \
# 0         T         H          I        S,A  ...            S            N
# 1         T         H          I          S  ...            S            N
# 2         T         H          I        S,A  ...            S            N
# 3         T         H          I        S,A  ...            S            N
# 4         T         H          I          S  ...            S            N
#
#   mdr1_1226[F] mdr1_1246[D] arps10_127-128[VD] fd_193[D] mdr2_484[T]  \
# 0            F            D                 VD         D           T
# 1            F            Y                 VD         D           T
# 2            F            D                 VD         D           T
# 3            F            D                 VD         D           T
# 4            F            D                 VD         D           T
#
#   kelch13_349-726_ns_changes mdr1_dup_call pm2_dup_call
# 0                        NaN             0            0
# 1                        NaN             0            0
# 2                        NaN             0            0
# 3                        NaN             0            0
# 4                        NaN             0            0
#
# [5 rows x 40 columns]

# %% [markdown]
# ##  Load all data into single DataFrame

# %% [markdown]
# We can merge these 3 datasets (metadata, drug resistance genotype and classification) to facilitate streamlined analysis.

# %%
pd.merge(qc_sample_metadata,drm_calls_fn,on='Sample')
# Out:
#           Sample                    Study     Country   Admin level 1  \
# 0       FP0008-C        1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# 1       FP0009-C        1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# 2      FP0010-CW        1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# 3      FP0011-CW        1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# 4      FP0012-CW        1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi
# ...          ...                      ...         ...             ...
# 24404   SPT92049       1306-PF-NG-NGWA-SM     Nigeria             Oyo
# 24405   SPT92054       1306-PF-NG-NGWA-SM     Nigeria             Oyo
# 24406   SPT92057       1306-PF-NG-NGWA-SM     Nigeria             Oyo
# 24407   SPT94772  1268-PF-MULTI-PAMGEN-SM      Gambia         Western
# 24408   SPT94773  1268-PF-MULTI-PAMGEN-SM      Gambia         Western
#
#        Country latitude  Country longitude  Admin level 1 latitude  \
# 0             20.265149         -10.337093               16.565426
# 1             20.265149         -10.337093               16.565426
# 2             20.265149         -10.337093               16.565426
# 3             20.265149         -10.337093               16.565426
# 4             20.265149         -10.337093               16.565426
# ...                 ...                ...                     ...
# 24404          9.592268           8.097575                8.143664
# 24405          9.592268           8.097575                8.143664
# 24406          9.592268           8.097575                8.143664
# 24407         13.451482         -15.372910               13.245396
# 24408         13.451482         -15.372910               13.245396
#
#        Admin level 1 longitude    Year          ENA  ... mdr1_1034[S]  \
# 0                    -9.832345  2014.0   ERR1081237  ...            S
# 1                    -9.832345  2014.0   ERR1081238  ...            S
# 2                    -9.832345  2014.0   ERR2889621  ...            S
# 3                    -9.832345  2014.0   ERR2889624  ...            S
# 4                    -9.832345  2014.0   ERR2889627  ...            S
# ...                        ...     ...          ...  ...          ...
# 24404                 3.618846  2019.0  ERR10893258  ...            S
# 24405                 3.618846  2019.0  ERR10893326  ...            S
# 24406                 3.618846  2019.0  ERR10893333  ...            S
# 24407               -16.401559  2017.0  ERR10789456  ...            -
# 24408               -16.401559  2017.0  ERR10789457  ...            S
#
#       mdr1_1042[N]  mdr1_1226[F]  mdr1_1246[D] arps10_127-128[VD] fd_193[D]  \
# 0                N             F             D                 VD         D
# 1                N             F             Y                 VD         D
# 2                N             F             D                 VD         D
# 3                N             F             D                 VD         D
# 4                N             F             D                 VD         D
# ...            ...           ...           ...                ...       ...
# 24404            N             F             -                 VD         D
# 24405            N             F             D                 VD         D
# 24406            N             F             D                 VD         D
# 24407            -             -             -                 VD         D
# 24408            N             F             D                 VD         D
#
#        mdr2_484[T] kelch13_349-726_ns_changes mdr1_dup_call pm2_dup_call
# 0                T                        NaN             0            0
# 1                T                        NaN             0            0
# 2                T                        NaN             0            0
# 3                T                        NaN             0            0
# 4                T                        NaN             0            0
# ...            ...                        ...           ...          ...
# 24404            T                          -            -1           -1
# 24405            T                        NaN             0           -1
# 24406            T                          -            -1           -1
# 24407            -                          -            -1           -1
# 24408            T                        NaN             0            0
#
# [24409 rows x 56 columns]

# %%
# Merge the dataframes on "Sample" column
df_all_sample_metadata = pd.merge(pd.merge(qc_sample_metadata,drm_calls_fn,on='Sample'),resistance_classification_fn,on='Sample')

# Print first 3 rows
df_all_sample_metadata.head(3)
# Out:
#       Sample              Study     Country   Admin level 1  Country latitude  \
# 0   FP0008-C  1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi         20.265149
# 1   FP0009-C  1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi         20.265149
# 2  FP0010-CW  1147-PF-MR-CONWAY  Mauritania  Hodh el Gharbi         20.265149
#
#    Country longitude  Admin level 1 latitude  Admin level 1 longitude    Year  \
# 0         -10.337093               16.565426                -9.832345  2014.0
# 1         -10.337093               16.565426                -9.832345  2014.0
# 2         -10.337093               16.565426                -9.832345  2014.0
#
#           ENA  ...   Chloroquine Pyrimethamine   Sulfadoxine  Mefloquine  \
# 0  ERR1081237  ...  Undetermined  Undetermined  Undetermined   Sensitive
# 1  ERR1081238  ...     Resistant     Resistant     Sensitive   Sensitive
# 2  ERR2889621  ...  Undetermined     Resistant     Resistant   Sensitive
#
#   Artemisinin Piperaquine  SP (uncomplicated)  SP (IPTp)      AS-MQ    DHA-PPQ
# 0   Sensitive   Sensitive           Sensitive  Sensitive  Sensitive  Sensitive
# 1   Sensitive   Sensitive           Resistant  Sensitive  Sensitive  Sensitive
# 2   Sensitive   Sensitive           Resistant  Sensitive  Sensitive  Sensitive
#
# [3 rows x 66 columns]

# %% [markdown]
# Sulfadoxine-Pyrimethamine (SP) is used for the treatment of uncomplicated cases and Intermittent Preventive Treatment in Pregnancy (IPTp). To make these two status clear in the dataset, we rename the columns.

# %%
# Define a dictionary of old&new column names
column_name_changes = collections.OrderedDict()
column_name_changes['SP (uncomplicated)'] = 'SP (treatment)'
column_name_changes['SP-IPTp'] = 'SP (IPTp)'

# Rename the columns using the dictionary
df_all_sample_metadata.rename(columns=column_name_changes, inplace=True)

# %% [markdown]
# ## Table setups

# %% [markdown]
# We proceed by defining a dictionary where each key represents a drug along with its associated gene, mutation, column name in the dataset, and sensitivity/resistance indicators.
#
# For details on the heuristics employed to map genetic markers to resistance status classification, please refer to [here](https://pf8-release.cog.sanger.ac.uk/Pf8_resistance_classification.pdf).

# %%
drm_dict = collections.OrderedDict()

drm_dict['Chloroquine'] = {
    'gene': 'crt',
    'mutation': '76T',
    'column_name': 'crt_76[K]',
    'sensitive': 'K',
    'resistant': 'T',
}

drm_dict['Pyrimethamine'] = {
    'gene': 'dhfr',
    'mutation': '108N',
    'column_name': 'dhfr_108[S]',
    'sensitive': 'S',
    'resistant': 'N',
}

drm_dict['Sulfadoxine'] = {
    'gene': 'dhps',
    'mutation': '437G',
    'column_name': 'dhps_437[G]',
    'sensitive': 'A',
    'resistant': 'G',
}

drm_dict['Mefloquine'] = {
    'gene': 'mdr1',
    'mutation': '2+ copies',
    'column_name': 'dup_mdr1',
    'sensitive': 0,
    'resistant': 1,
}

drm_dict['Artemisinin'] = {
    'gene': 'kelch13',
    'mutation': 'WHO list',
    'column_name': None,
}

drm_dict['Piperaquine'] = {
    'gene': 'plasmepsin 2-3',
    'mutation': '2+ copies',
    'column_name': 'dup_pm2',
    'sensitive': 0,
    'resistant': 1,
}

drm_dict['SP (treatment)'] = {
    'gene': 'dhfr',
    'mutation': 'triple mutant',
    'column_name': None
}

drm_dict['SP (IPTp)'] = {
    'gene': 'dhfr and dhps',
    'mutation': 'sextuple mutant',
    'column_name': None
}

drm_dict['AS-MQ'] = {
    'gene': 'kelch13 and mdr1',
    'mutation': '',
    'column_name': None
}

drm_dict['DHA-PPQ'] = {
    'gene': 'kelch13 and plasmepsin 2-3',
    'mutation': '',
    'column_name': None
}

# %% [markdown]
# To elaborate on population names in the final table, we define a dictionary listing ten populations with the following abbreviations:

# %%
populations = collections.OrderedDict()
populations['SA']       = "South America"
populations['AF-W']     = "Africa - West"
populations['AF-C']     = "Africa - Central"
populations['AF-NE']    = "Africa - Northeast"
populations['AF-E']     = "Africa - East"
populations['AS-S-E']  = "Asia - South - East"
populations['AS-S-FE']  = "Asia - South - Far East"
populations['AS-SE-W'] = "Asia - Southeast - West"
populations['AS-SE-E'] = "Asia - Southeast - East"
populations['OC-NG']    = "Oceania - New Guinea"

# %% [markdown]
# ## Summary of DR sample sizes across populations

# %% [markdown]
# We want to create a table summarizing the number of samples by population.
#
# To do this, we will write a function that counts number of samples that are resistant and sensitive for a given drug.

# %%
def n_agg(x):
    """
    Aggregate function to calculate the count of non-undetermined samples for each drug in a given population.

    Parameters:
    - x: DataFrame

    Returns:
    - pd.Series: Counts of sensitive samples that are resistant to each drug.
    """

    # Initialize an ordered dictionary to store drug names and their corresponding counts
    names = collections.OrderedDict()

    # Iterate through each drug in drm_dict
    for drug in drm_dict:
        # Count the number of non-undetermined samples for the current drug
        n = np.count_nonzero((x[drug] != 'Undetermined'))

        # Store the drug name and its count in the dictionary
        names[drug] = n

    # Return the result as a pandas Series
    return pd.Series(names)

# %% [markdown]
# As an addition to table, we would like to include minimum and maximum drug resistance sample size in the population names.

# %%
# Calculate counts of non-undetermined samples for each drug in each population
df_drm_n_table = (
    df_all_sample_metadata
    .groupby('Population')
    .apply(n_agg, include_groups=False)
    .rename_axis(None)
    .transpose()
    .loc[:, populations.keys()]
    .reset_index()
)

# Calculate the minimum and maximum sample sizes across populations
min_n = df_drm_n_table.min()
max_n = df_drm_n_table.max()

# Customize the index to include gene and mutation information for each drug
df_drm_n_table.index = ["%s %s" % (drm_dict[drug]['gene'], drm_dict[drug]['mutation']) for drug in drm_dict]
df_drm_n_table.index.names = ['Marker']

# Rename the columns to indicate their association with drug resistance and sample counts
df_drm_n_table.rename(columns={'index': 'Associated with resistance to'}, inplace=True)

# Update column names to include population names and corresponding sample size ranges
for population in populations:
    new_column_name = f'{populations[population]} (n={min_n[population]}-{max_n[population]})'
    df_drm_n_table.rename(columns={population: new_column_name}, inplace=True)

# Display the final drug resistance count table
df_drm_n_table
# Out:
#                               Associated with resistance to  \
# Marker
# crt 76T                                         Chloroquine
# dhfr 108N                                     Pyrimethamine
# dhps 437G                                       Sulfadoxine
# mdr1 2+ copies                                   Mefloquine
# kelch13 WHO list                                Artemisinin
# plasmepsin 2-3 2+ copies                        Piperaquine
# dhfr triple mutant                           SP (treatment)
# dhfr and dhps sextuple mutant                     SP (IPTp)
# kelch13 and mdr1                                      AS-MQ
# kelch13 and plasmepsin 2-3                          DHA-PPQ
#
#                                South America (n=177-224)  \
# Marker
# crt 76T                                              223
# dhfr 108N                                            217
# dhps 437G                                            224
# mdr1 2+ copies                                       177
# kelch13 WHO list                                     180
# plasmepsin 2-3 2+ copies                             182
# dhfr triple mutant                                   224
# dhfr and dhps sextuple mutant                        224
# kelch13 and mdr1                                     199
# kelch13 and plasmepsin 2-3                           190
#
#                                Africa - West (n=6648-8837)  \
# Marker
# crt 76T                                               8284
# dhfr 108N                                             8035
# dhps 437G                                             8007
# mdr1 2+ copies                                        6936
# kelch13 WHO list                                      7220
# plasmepsin 2-3 2+ copies                              6648
# dhfr triple mutant                                    7474
# dhfr and dhps sextuple mutant                         8837
# kelch13 and mdr1                                      7846
# kelch13 and plasmepsin 2-3                            7524
#
#                                Africa - Central (n=870-1184)  \
# Marker
# crt 76T                                                 1039
# dhfr 108N                                               1184
# dhps 437G                                               1155
# mdr1 2+ copies                                           923
# kelch13 WHO list                                         938
# plasmepsin 2-3 2+ copies                                 870
# dhfr triple mutant                                      1058
# dhfr and dhps sextuple mutant                           1138
# kelch13 and mdr1                                        1059
# kelch13 and plasmepsin 2-3                               981
#
#                                Africa - Northeast (n=122-204)  \
# Marker
# crt 76T                                                   196
# dhfr 108N                                                 200
# dhps 437G                                                 196
# mdr1 2+ copies                                            125
# kelch13 WHO list                                          151
# plasmepsin 2-3 2+ copies                                  122
# dhfr triple mutant                                        201
# dhfr and dhps sextuple mutant                             204
# kelch13 and mdr1                                          160
# kelch13 and plasmepsin 2-3                                157
#
#                                Africa - East (n=3599-4000)  \
# Marker
# crt 76T                                               3944
# dhfr 108N                                             4000
# dhps 437G                                             3871
# mdr1 2+ copies                                        3707
# kelch13 WHO list                                      3712
# plasmepsin 2-3 2+ copies                              3599
# dhfr triple mutant                                    3646
# dhfr and dhps sextuple mutant                         3980
# kelch13 and mdr1                                      3940
# kelch13 and plasmepsin 2-3                            3804
#
#                                Asia - South - East (n=81-188)  \
# Marker
# crt 76T                                                   178
# dhfr 108N                                                 162
# dhps 437G                                                 179
# mdr1 2+ copies                                             93
# kelch13 WHO list                                          144
# plasmepsin 2-3 2+ copies                                   81
# dhfr triple mutant                                        186
# dhfr and dhps sextuple mutant                             188
# kelch13 and mdr1                                          157
# kelch13 and plasmepsin 2-3                                149
#
#                                Asia - South - Far East (n=1209-1369)  \
# Marker
# crt 76T                                                         1330
# dhfr 108N                                                       1369
# dhps 437G                                                       1296
# mdr1 2+ copies                                                  1241
# kelch13 WHO list                                                1335
# plasmepsin 2-3 2+ copies                                        1248
# dhfr triple mutant                                              1209
# dhfr and dhps sextuple mutant                                   1216
# kelch13 and mdr1                                                1350
# kelch13 and plasmepsin 2-3                                      1350
#
#                                Asia - Southeast - West (n=1665-1884)  \
# Marker
# crt 76T                                                         1877
# dhfr 108N                                                       1884
# dhps 437G                                                       1884
# mdr1 2+ copies                                                  1739
# kelch13 WHO list                                                1775
# plasmepsin 2-3 2+ copies                                        1779
# dhfr triple mutant                                              1837
# dhfr and dhps sextuple mutant                                   1665
# kelch13 and mdr1                                                1795
# kelch13 and plasmepsin 2-3                                      1824
#
#                                Asia - Southeast - East (n=2910-5798)  \
# Marker
# crt 76T                                                         5798
# dhfr 108N                                                       5796
# dhps 437G                                                       5728
# mdr1 2+ copies                                                  4966
# kelch13 WHO list                                                5295
# plasmepsin 2-3 2+ copies                                        4868
# dhfr triple mutant                                              5689
# dhfr and dhps sextuple mutant                                   2910
# kelch13 and mdr1                                                5087
# kelch13 and plasmepsin 2-3                                      4949
#
#                                Oceania - New Guinea (n=293-340)
# Marker
# crt 76T                                                     331
# dhfr 108N                                                   332
# dhps 437G                                                   331
# mdr1 2+ copies                                              307
# kelch13 WHO list                                            302
# plasmepsin 2-3 2+ copies                                    293
# dhfr triple mutant                                          338
# dhfr and dhps sextuple mutant                               340
# kelch13 and mdr1                                            320
# kelch13 and plasmepsin 2-3                                  313

# %% [markdown]
# **Table 1.** Numbers of samples used to determine proportions in Table 2.

# %% [markdown]
# To save the table:

# %%
df_drm_n_table.to_excel("DRM_table_sample_numbers.xlsx")

# %% [markdown]
# ## Summary of DR frequencies across populations

# %% [markdown]
# Now, we would like to calculate drug resistance proportions in each population.
#
# We can easily adjust the function to count number of samples that are resistant and sensitive for a given drug, and calculate the proportion.

# %%
def proportion_agg(x):
    """
    Aggregate function to calculate the proportion of resistance for each drug in a given population.

    Parameters:
    - x: DataFrame

    Returns:
    - pd.Series: Proportions of resistance for each drug.
    """

    # Initialize an ordered dictionary to store drug names and their corresponding proportions
    names = collections.OrderedDict()

    # Iterate through each drug in drm_dict
    for drug in drm_dict:
        # Count the number of non-undetermined samples for the current drug
        n = np.count_nonzero((x[drug] != 'Undetermined'))

        # Check if there are no non-undetermined samples for the drug
        if n == 0:
            proportion = np.nan  # Set proportion to NaN to avoid division by zero
        else:
            # Calculate the proportion of resistant samples for the drug
            proportion = round(np.count_nonzero(
                (x[drug] == 'Resistant')
            ) / np.count_nonzero(
                (x[drug] != 'Undetermined')
            )*100)

        # Store the drug name and its proportion in the dictionary
        names[drug] = proportion

    # Return the result as a pandas Series
    return pd.Series(names)

# %% [markdown]
# Let's apply this function and create a table summarizing drug resistance proportions by population.

# %%
# Create a table summarizing drug resistance proportions by population

# Group the DataFrame by 'Population' and apply the 'proportion_agg' function to calculate resistance proportions
df_drm_table = (
    df_all_sample_metadata
    .groupby('Population')
    .apply(proportion_agg, include_groups=False)
    .rename_axis(None)
    .transpose()
    .loc[:, populations.keys()]
    .reset_index()
)

# Customize the index to include gene and mutation information for each drug
df_drm_table.index = ["%s %s" % (drm_dict[drug]['gene'], drm_dict[drug]['mutation']) for drug in drm_dict]
df_drm_table.index.names = ['Marker']

# Rename the columns to indicate their association with drug resistance
df_drm_table.rename(columns={'index': 'Associated with resistance to'}, inplace=True)

# Update column names to include population names and corresponding sample size ranges
for population in populations:
    new_column_name = f'{populations[population]} (n={min_n[population]}-{max_n[population]})'
    df_drm_table.rename(columns={population: new_column_name}, inplace=True)

# Add '%' symbol to all values in the table
df_drm_table = df_drm_table.map(lambda x: f"{int(x)}%" if isinstance(x, (int, float)) else x)

# Display the final drug resistance table
df_drm_table
# Out:
#                               Associated with resistance to  \
# Marker
# crt 76T                                         Chloroquine
# dhfr 108N                                     Pyrimethamine
# dhps 437G                                       Sulfadoxine
# mdr1 2+ copies                                   Mefloquine
# kelch13 WHO list                                Artemisinin
# plasmepsin 2-3 2+ copies                        Piperaquine
# dhfr triple mutant                           SP (treatment)
# dhfr and dhps sextuple mutant                     SP (IPTp)
# kelch13 and mdr1                                      AS-MQ
# kelch13 and plasmepsin 2-3                          DHA-PPQ
#
#                               South America (n=177-224)  \
# Marker
# crt 76T                                            100%
# dhfr 108N                                           74%
# dhps 437G                                           71%
# mdr1 2+ copies                                       0%
# kelch13 WHO list                                     0%
# plasmepsin 2-3 2+ copies                             0%
# dhfr triple mutant                                   0%
# dhfr and dhps sextuple mutant                        0%
# kelch13 and mdr1                                     0%
# kelch13 and plasmepsin 2-3                           0%
#
#                               Africa - West (n=6648-8837)  \
# Marker
# crt 76T                                               26%
# dhfr 108N                                             89%
# dhps 437G                                             81%
# mdr1 2+ copies                                         0%
# kelch13 WHO list                                       0%
# plasmepsin 2-3 2+ copies                               0%
# dhfr triple mutant                                    79%
# dhfr and dhps sextuple mutant                          0%
# kelch13 and mdr1                                       0%
# kelch13 and plasmepsin 2-3                             0%
#
#                               Africa - Central (n=870-1184)  \
# Marker
# crt 76T                                                 35%
# dhfr 108N                                               99%
# dhps 437G                                               96%
# mdr1 2+ copies                                           0%
# kelch13 WHO list                                         0%
# plasmepsin 2-3 2+ copies                                 0%
# dhfr triple mutant                                      88%
# dhfr and dhps sextuple mutant                            5%
# kelch13 and mdr1                                         0%
# kelch13 and plasmepsin 2-3                               0%
#
#                               Africa - Northeast (n=122-204)  \
# Marker
# crt 76T                                                  48%
# dhfr 108N                                                98%
# dhps 437G                                                79%
# mdr1 2+ copies                                            0%
# kelch13 WHO list                                          0%
# plasmepsin 2-3 2+ copies                                  0%
# dhfr triple mutant                                       51%
# dhfr and dhps sextuple mutant                             2%
# kelch13 and mdr1                                          0%
# kelch13 and plasmepsin 2-3                                0%
#
#                               Africa - East (n=3599-4000)  \
# Marker
# crt 76T                                               14%
# dhfr 108N                                             97%
# dhps 437G                                             86%
# mdr1 2+ copies                                         0%
# kelch13 WHO list                                       0%
# plasmepsin 2-3 2+ copies                               0%
# dhfr triple mutant                                    83%
# dhfr and dhps sextuple mutant                          4%
# kelch13 and mdr1                                       0%
# kelch13 and plasmepsin 2-3                             0%
#
#                               Asia - South - East (n=81-188)  \
# Marker
# crt 76T                                                  33%
# dhfr 108N                                                62%
# dhps 437G                                                 9%
# mdr1 2+ copies                                            0%
# kelch13 WHO list                                          0%
# plasmepsin 2-3 2+ copies                                  0%
# dhfr triple mutant                                        2%
# dhfr and dhps sextuple mutant                             0%
# kelch13 and mdr1                                          0%
# kelch13 and plasmepsin 2-3                                0%
#
#                               Asia - South - Far East (n=1209-1369)  \
# Marker
# crt 76T                                                         94%
# dhfr 108N                                                      100%
# dhps 437G                                                       89%
# mdr1 2+ copies                                                   0%
# kelch13 WHO list                                                 0%
# plasmepsin 2-3 2+ copies                                         0%
# dhfr triple mutant                                              46%
# dhfr and dhps sextuple mutant                                   13%
# kelch13 and mdr1                                                 0%
# kelch13 and plasmepsin 2-3                                       0%
#
#                               Asia - Southeast - West (n=1665-1884)  \
# Marker
# crt 76T                                                         99%
# dhfr 108N                                                      100%
# dhps 437G                                                      100%
# mdr1 2+ copies                                                  30%
# kelch13 WHO list                                                36%
# plasmepsin 2-3 2+ copies                                         0%
# dhfr triple mutant                                              86%
# dhfr and dhps sextuple mutant                                   79%
# kelch13 and mdr1                                                10%
# kelch13 and plasmepsin 2-3                                       0%
#
#                               Asia - Southeast - East (n=2910-5798)  \
# Marker
# crt 76T                                                         96%
# dhfr 108N                                                       99%
# dhps 437G                                                       83%
# mdr1 2+ copies                                                   4%
# kelch13 WHO list                                                62%
# plasmepsin 2-3 2+ copies                                        43%
# dhfr triple mutant                                              87%
# dhfr and dhps sextuple mutant                                   12%
# kelch13 and mdr1                                                 3%
# kelch13 and plasmepsin 2-3                                      39%
#
#                               Oceania - New Guinea (n=293-340)
# Marker
# crt 76T                                                    96%
# dhfr 108N                                                  99%
# dhps 437G                                                  69%
# mdr1 2+ copies                                              1%
# kelch13 WHO list                                            1%
# plasmepsin 2-3 2+ copies                                    0%
# dhfr triple mutant                                          0%
# dhfr and dhps sextuple mutant                               0%
# kelch13 and mdr1                                            0%
# kelch13 and plasmepsin 2-3                                  0%

# %% [markdown]
# **Table 2.** Frequency of different sets of polymorphisms associated with drug resistance in samples from different geographical regions.
# All samples were classified into different types of drug resistance based on published genetic markers, and represent best attempt based on the available data. Each type of resistance was considered to be either present, absent or unknown for a given sample. For each resistance type, the table reports: the genetic markers considered; the drug they are associated with; the proportion of samples in each major sub-population classified as resistant out of the samples where the type was not unknown. The number of samples classified as either resistant or not resistant varies for each type of resistance considered (e.g. due to different levels of genomic accessibility); numbers in brackets report the minimum and maximum number analysed while the exact numbers considered are reported in Table 1 of this notebook. SP: sulfadoxine-pyrimethamine; treatment: SP used for the clinical treatment of uncomplicated malaria; IPTp: SP used for intermittent preventive treatment in pregnancy; AS-MQ: artesunate + mefloquine combination therapy; DHA-PPQ: dihydroartemisinin + piperaquine combination therapy. *dhfr* triple mutant refers to having all three of 51I, 59R and 108N in *dhfr*. *dhfr* and *dhps* sextuple mutant refers to having all five of 51I, 59R and 108N in *dhfr* and 437G and 540E in *dhps*, plus one of *dhfr*:164L, *dhps*:581G, *dhps*:613S or *dhps*:613T. Full details of the rules used to infer resistance status from genetic markers can be found [here](https://pf8-release.cog.sanger.ac.uk/Pf8_resistance_classification.pdf).

# %% [markdown]
# To save the table:

# %%
df_drm_table.to_excel("DRM_table.xlsx")
